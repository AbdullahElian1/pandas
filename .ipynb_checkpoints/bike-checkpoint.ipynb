# %%
#What is the average trip duration for a borrowed bicycle?

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./trip.csv',error_bad_lines=False)
df
# Out:
# /home/abdullah/.cache/pypoetry/virtualenvs/vg-stats-V7JwTET8-py3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 50794: expected 12 fields, saw 20\n'
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# ...         ...               ...               ...       ...           ...
# 286852   255241   8/31/2016 23:34   8/31/2016 23:45  SEA00201       679.532
# ...

# %%
#What is the average trip duration for a borrowed bicycle?

# %%
duration=df["tripduration"].mean()
duration
# Out:
# 1178.2956753399776

# %%
#What’s the most common age of a bicycle-sharer?

# %%
age=df.birthyear.mode()
age=2021-age
age
# Out:
# 0    34.0
# dtype: float64

# %%
df_weather=pd.read_csv('weather.csv')
df_weather
# Out:
#            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0    10/13/2014                 71                62.0                54
# 1    10/14/2014                 63                59.0                55
# 2    10/15/2014                 62                58.0                54
# 3    10/16/2014                 71                61.0                52
# 4    10/17/2014                 64                60.0                57
# ..          ...                ...                 ...               ...
# 684   8/27/2016                 72                66.0                61
# 685   8/28/2016                 75                68.0                59
# 686   8/29/2016                 81                68.0                55
# 687   8/30/2016                 70                64.0                57
# 688   8/31/2016                 71                65.0                59
#
#      Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# ...

# %%
#Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
avg_precipitation = df_weather['Precipitation_In'].mean()*30

median_precipitation = df_weather['Precipitation_In'].median()*30

print (f"({median_precipitation_per_month} ,{avg_precipitation_per_month})")
# Out:
# (0.0 ,3.1519593613933234)

# %%
#What’s the average number of bikes at a given bike station?

# %%
df_station= pd.read_csv('station.csv')
df_station
avg = df_station['install_dockcount'].mean()
avg =np.round_(avg)
avg
# Out:
# 18.0

# %%
#When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?

# %%
get_bikes=df_station[["modification_date","install_dockcount"]].dropna()
get_bikes
loss_bikes=x["install_dockcount"].sum()- df_station["install_dockcount"].sum()
loss_bikes
# Out:
# -722

# %%
#What is the average max temperature in fahrenheit?

# %%
average_max_temp=df_weather['Max_Temperature_F'].mean()
average_max_temp
# Out:
# 64.02757619738752

# %%
# Give me the average of tripduration

# %%
avg_year = df["birthyear"].mean()
avg_year
# Out:
# 1979.7590620920612

# %%
#What is the average minimum temperature in fahrenheit?

# %%
average_min_temp=df_weather['Min_TemperatureF'].mean()
average_min_temp
# Out:
# 49.45428156748911

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

        assert_equal(duration, 1178.2956753399776)
        assert_equal(age, 34)
        assert_equal(avg, 18.0)
        assert_equal(median_precipitation, 0.0)
        assert_equal(avg_precipitation,3.1519593613933234)
        assert_equal(avg_year ,1979.7590620920612)
        assert_equal(loss_bikes,-722)



    print("Success!!!")

test()
# Out:
# Success!!!
